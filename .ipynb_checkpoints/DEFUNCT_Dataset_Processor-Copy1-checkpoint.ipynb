# %%
import os
import utils
import subprocess
import random
from subprocess import  check_output, CalledProcessError, STDOUT

# %% [markdown]
# # Target dataset processor

# %% [markdown]
# #### Add names of target datasets to process here

# %%
datasetnames = ["YourName"] #folders containing datasets videos
extensions = ('.mp4', '.mkv', '.avi') #acceptable video extensions
exclusions = [] #original videos to not process, by filename

# %%
#split all videos in each dataset folder into scenes, dump scenes into unified dest folder
for datasetname in datasetnames:
    videolist = os.listdir("data/videos/tgts/" + datasetname)
    for videoname in videolist:
        if not videoname.lower().endswith(extensions) or videoname in exclusions:
            continue
        command = ("scenedetect -i " 
                  + "data/videos/tgts/" + datasetname + "/" + videoname + " "
                  + "-o " + "data/videos/tgts_scenes/" + datasetname + " " 
                  + "detect-content split-video")
        print(command)
        os.system(command)
# Out:
# scenedetect -i data/videos/tgts/YourName/YourName.mp4 -o data/videos/tgts_scenes/YourName detect-content split-video

# %%
#split all scenes into frames, dump frames into dest dataset folder separated by scene
#ignore the first three frames of each scene for anime as scenedetect 
#seems to hold them from the previous scene

for datasetname in datasetnames:
    scenelist = os.listdir("data/videos/tgts_scenes/" + datasetname)
    
    try: #make dest folder if doesn't exist
        os.mkdir("data/AnimeGAN_data/target_datasets/" + datasetname)
    except OSError:
        pass
    
    for scene in scenelist:
        if not scene.lower().endswith(extensions): #skip junk files
            continue
        print("Splitting " + scene)
        inpath = "data/videos/tgts_scenes/" + datasetname + "/" + scene
        outfolder = "data/AnimeGAN_data/target_datasets/" + datasetname + "/" + scene
        frameoutfolder = "data/img_datasets/target_img_datasets/" + datasetname
        utils.FrameCapture(inpath, outfolder, div = 24, startFrame = 3)
        utils.FrameCapture(inpath, frameoutfolder, div = 1, clearoutfolder = False)
# Out:
# Splitting YourName-Scene-0855.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0855.mp4
# Splitting YourName-Scene-0581.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0581.mp4
# Splitting YourName-Scene-0605.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0605.mp4
# Splitting YourName-Scene-1253.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-1253.mp4
# Splitting YourName-Scene-0436.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0436.mp4
# Splitting YourName-Scene-1229.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-1229.mp4
# Splitting YourName-Scene-0499.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0499.mp4
# Splitting YourName-Scene-1469.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-1469.mp4
# Splitting YourName-Scene-0584.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0584.mp4
# Splitting YourName-Scene-0191.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0191.mp4
# Splitting YourName-Scene-1517.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-1517.mp4
# Splitting YourName-Scene-0303.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0303.mp4
# Splitting YourName-Scene-0437.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0437.mp4
# Splitting YourName-Scene-1062.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-1062.mp4
# Splitting YourName-Scene-1348.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-1348.mp4
# Splitting YourName-Scene-0987.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0987.mp4
# Splitting YourName-Scene-0087.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0087.mp4
# Splitting YourName-Scene-0256.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0256.mp4
# Splitting YourName-Scene-0276.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0276.mp4
# Splitting YourName-Scene-1204.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-1204.mp4
# Splitting YourName-Scene-0382.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-
mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0774.mp4
# Splitting YourName-Scene-1069.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-1069.mp4
# Splitting YourName-Scene-0019.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0019.mp4
# Splitting YourName-Scene-0296.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0296.mp4
# Splitting YourName-Scene-0298.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0298.mp4
# Splitting YourName-Scene-1188.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-1188.mp4
# Splitting YourName-Scene-0220.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0220.mp4
# Splitting YourName-Scene-0495.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0495.mp4
# Splitting YourName-Scene-0187.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0187.mp4
# Splitting YourName-Scene-0102.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0102.mp4
# Splitting YourName-Scene-0354.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0354.mp4
# Splitting YourName-Scene-0902.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0902.mp4
# Splitting YourName-Scene-0363.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0363.mp4
# Splitting YourName-Scene-0604.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0604.mp4
# Splitting YourName-Scene-0972.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0972.mp4
# Splitting YourName-Scene-1064.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-1064.mp4
# Splitting YourName-Scene-1327.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-1327.mp4
# Splitting YourName-Scene-0116.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0116.mp4
# Splitting YourName-Scene-1369.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-1369.mp4
# Splitting YourName-Scene-0710.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0710.mp4
# Splitting YourName-Scene-0560.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0560.mp4
# Splitting YourName-Scene-0092.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0092.mp4
# Splitting YourName-Scene-0505.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0505.mp4
# Splitting YourName-Scene-0920.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0920.mp4
# Splitting YourName-Scene-0686.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0686.mp4
# Splitting YourName-Scene-1221.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-1221.mp4
# Splitting YourName-Scene-0542.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0542.mp4
# Splitting YourName-Scene-0497.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0497.mp4
# Splitting YourName-Scene-0032.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0032.mp4
# Splitting YourName-Scene-0978.mp4
# Successfully created the directory data/AnimeGAN_data/target_datasets/YourName/YourName-Scene-0978.mp4

# %%
#TODO: EDGE-PROMOTING and CROPPING for both image and scenes

# %% [markdown]
# # Source dataset processor

# %%
#https://stackoverflow.com/questions/3844430/how-to-get-the-duration-of-a-video-in-python
def getDuration(filename):
    command = [
        'ffprobe', 
        '-v', 
        'error', 
        '-show_entries', 
        'format=duration', 
        '-of', 
        'default=noprint_wrappers=1:nokey=1', 
        filename
      ]

    try:
        output = check_output( command, stderr=STDOUT ).decode()
    except CalledProcessError as e:
        output = e.output.decode()

    return output

# %%
videolist = os.listdir("data/videos/src/")
for videoname in videolist:
    if not videoname.lower().endswith(('.mp4')):
        continue
    vidpath = "data/videos/src/" + videoname
    if float(getDuration(vidpath)) < 12.0:
        continue
    command = ("scenedetect -i " 
              + "data/videos/src/" + videoname + " "
              + "-o " + "data/videos/src_scenes" + " " 
              + "detect-content split-video")
    print(command)
    os.system(command)
# Out:
# scenedetect -i data/videos/src/actioncliptrain00414.avi -o data/videos/src_scenes detect-content split-video
# scenedetect -i data/videos/src/sceneclipautoautotrain00347.avi -o data/videos/src_scenes detect-content split-video
# scenedetect -i data/videos/src/actioncliptest00213.avi -o data/videos/src_scenes detect-content split-video
# scenedetect -i data/videos/src/actionclipautoautotrain00087.avi -o data/videos/src_scenes detect-content split-video
# scenedetect -i data/videos/src/actionclipautoautotrain00155.avi -o data/videos/src_scenes detect-content split-video
# scenedetect -i data/videos/src/sceneclipautoautotrain00225.avi -o data/videos/src_scenes detect-content split-video
# scenedetect -i data/videos/src/actioncliptrain00509.avi -o data/videos/src_scenes detect-content split-video
# scenedetect -i data/videos/src/sceneclipautoautotrain00461.avi -o data/videos/src_scenes detect-content split-video
# scenedetect -i data/videos/src/sceneclipautoautotrain00510.avi -o data/videos/src_scenes detect-content split-video
# scenedetect -i data/videos/src/sceneclipautoautotrain00386.avi -o data/videos/src_scenes detect-content split-video
# scenedetect -i data/videos/src/actioncliptrain00367.avi -o data/videos/src_scenes detect-content split-video
# scenedetect -i data/videos/src/actioncliptest00445.avi -o data/videos/src_scenes detect-content split-video
# scenedetect -i data/videos/src/actioncliptrain00500.avi -o data/videos/src_scenes detect-content split-video
# scenedetect -i data/videos/src/actionclipautoautotrain00743.avi -o data/videos/src_scenes detect-content split-video
# scenedetect -i data/videos/src/actionclipautoautotrain00294.avi -o data/videos/src_scenes detect-content split-video
# scenedetect -i data/videos/src/actioncliptest00560.avi -o data/videos/src_scenes detect-content split-video
# scenedetect -i data/videos/src/scenecliptest00368.avi -o data/videos/src_scenes detect-content split-video
# scenedetect -i data/videos/src/actioncliptrain00305.avi -o data/videos/src_scenes detect-content split-video
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-521cbc35c2af> in <module>
#       4         continue
#       5     vidpath = "data/videos/src/" + videoname
# ----> 6     if float(getDuration(vidpath)) < 12.0:
#       7         continue
#       8     command = ("scenedetect -i "
#
# <ipython-input-5-60a3d94519fc> in getDuration(filename)
#      13
#      14     try:
# ---> 15         output = check_output( command, stderr=STDOUT ).decode()
#      16     except CalledProcessError as e:
#      17         output = e.output.decode()
#
# /opt/anaconda3/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     393
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#     397
#
# /opt/anaconda3/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     472     with Popen(*popenargs, **kwargs) as process:
#     473         try:
# --> 474             stdout, stderr = process.communicate(input, timeout=timeout)
#     475         except TimeoutExpired:
#     476             process.kill()
#
# /opt/anaconda3/lib/python3.7/subprocess.py in communicate(self, input, timeout)
#     924                 self._stdin_write(input)
#     925             elif self.stdout:
# --> 926                 stdout = self.stdout.read()
#     927                 self.stdout.close()
#     928             elif self.stderr:
#
# KeyboardInterrupt:

# %%
scenelist = os.listdir("data/videos/src_scenes/")
    
for scene in scenelist:
    if not scene.lower().endswith(extensions): #skip junk files
        continue
    print("Splitting " + scene)
    inpath = "data/videos/src_scenes/" + scene
    outfolder = "data/AnimeGAN_data/src_data/" + scene
    frameoutfolder = "data/img_datasets/src_img/"
    utils.FrameCapture(inpath, outfolder, div = 24, startframe = 240)
    utils.FrameCapture(inpath, frameoutfolder, div = 1, startframe = 10, clearoutfolder = False)

# %%
#TODO: CROPPING for both image and scenes
